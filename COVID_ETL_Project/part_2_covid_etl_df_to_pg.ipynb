# %%
import pandas as pd
from sqlalchemy import create_engine

# PostgreSQL connection string components
database_username = '*******************'
database_password = '*******************'
database_ip       = 'localhost'
database_name     = 'covid_db'
database_port     = '5432'  # default PostgreSQL port

# create the connection string
database_connection = create_engine('postgresql+psycopg2://{0}:{1}@{2}:{3}/{4}'.format(
    database_username, database_password, database_ip, database_port, database_name))

# %%
# load the data from CSV
alleninstitute_comprehend_medical = pd.read_csv('*******************/covid_etl_raw_data/alleninstitute_comprehend_medical.csv')
alleninstitute_metadata = pd.read_csv('*******************/covid_etl_raw_data/alleninstitute_metadata.csv')
aspirevc_crowd_tracing = pd.read_csv('*******************/covid_etl_raw_data/aspirevc_crowd_tracing.csv')
aspirevc_crowd_tracing_zipcode_3digits = pd.read_csv('*******************/covid_etl_raw_data/aspirevc_crowd_tracing_zipcode_3digits.csv')
cdc_moderna_vaccine_distribution = pd.read_csv('*******************/covid_etl_raw_data/cdc_moderna_vaccine_distribution.csv')
cdc_pfizer_vaccine_distribution = pd.read_csv('*******************/covid_etl_raw_data/cdc_pfizer_vaccine_distribution.csv')
country_codes = pd.read_csv('*******************/covid_etl_raw_data/country_codes.csv')
county_populations = pd.read_csv('*******************/covid_etl_raw_data/county_populations.csv')
covid_knowledge_graph_edges = pd.read_csv('*******************/covid_etl_raw_data/covid_knowledge_graph_edges.csv')
covid_knowledge_graph_nodes_author = pd.read_csv('*******************/covid_etl_raw_data/covid_knowledge_graph_nodes_author.csv')
covid_knowledge_graph_nodes_concept = pd.read_csv('*******************/covid_etl_raw_data/covid_knowledge_graph_nodes_concept.csv')
covid_knowledge_graph_nodes_institution = pd.read_csv('*******************/covid_etl_raw_data/covid_knowledge_graph_nodes_institution.csv')
covid_knowledge_graph_nodes_paper = pd.read_csv('*******************/covid_etl_raw_data/covid_knowledge_graph_nodes_paper.csv')
covid_knowledge_graph_nodes_topic = pd.read_csv('*******************/covid_etl_raw_data/covid_knowledge_graph_nodes_topic.csv')
covid_testing_states_daily = pd.read_csv('*******************/covid_etl_raw_data/covid_testing_states_daily.csv')
covid_testing_us_daily = pd.read_csv('*******************/covid_etl_raw_data/covid_testing_us_daily.csv')
covid_testing_us_total = pd.read_csv('*******************/covid_etl_raw_data/covid_testing_us_total.csv')
covidcast_data = pd.read_csv('*******************/covid_etl_raw_data/covidcast_data.csv')
covidcast_metadata = pd.read_csv('*******************/covid_etl_raw_data/covidcast_metadata.csv')
enigma_aggregation_global = pd.read_csv('*******************/covid_etl_raw_data/enigma_aggregation_global.csv')
enigma_aggregation_global_countries = pd.read_csv('*******************/covid_etl_raw_data/enigma_aggregation_global_countries.csv')
enigma_aggregation_us_counties = pd.read_csv('*******************/covid_etl_raw_data/enigma_aggregation_us_counties.csv')
enigma_aggregation_us_states = pd.read_csv('*******************/covid_etl_raw_data/enigma_aggregation_us_states.csv')
enigma_jhu = pd.read_csv('*******************/covid_etl_raw_data/enigma_jhu.csv')
enigma_jhu_timeseries = pd.read_csv('*******************/covid_etl_raw_data/enigma_jhu_timeseries.csv')
hospital_beds = pd.read_csv('*******************/covid_etl_raw_data/hospital_beds.csv')
nytimes_counties = pd.read_csv('*******************/covid_etl_raw_data/nytimes_counties.csv')
nytimes_states = pd.read_csv('*******************/covid_etl_raw_data/nytimes_states.csv')
owid_us_state_vaccinations = pd.read_csv('*******************/covid_etl_raw_data/owid_us_state_vaccinations.csv')
owid_world_vaccinations = pd.read_csv('*******************/covid_etl_raw_data/owid_world_vaccinations.csv')
owid_world_vaccinations_by_manufacturer = pd.read_csv('*******************/covid_etl_raw_data/owid_world_vaccinations_by_manufacturer.csv')
prediction_models_county_predictions = pd.read_csv('*******************/prediction_models_county_predictions.csv')
prediction_models_severity_index = pd.read_csv('*******************/covid_etl_raw_data/prediction_models_severity_index.csv')
tableau_covid_datahub = pd.read_csv('*******************/covid_etl_raw_data/tableau_covid_datahub.csv')
tableau_jhu = pd.read_csv('*******************/covid_etl_raw_data/tableau_jhu.csv')
uk_covid = pd.read_csv('*******************/covid_etl_raw_data/uk_covid.csv')
us_state_abbreviations = pd.read_csv('*******************/covid_etl_raw_data/us_state_abbreviations.csv')
world_cases_deaths_testing = pd.read_csv('*******************/covid_etl_raw_data/world_cases_deaths_testing.csv')

# %%
# write data into the database
alleninstitute_comprehend_medical.to_sql('alleninstitute_comprehend_medical', database_connection, if_exists='replace')
alleninstitute_metadata.to_sql('alleninstitute_metadata', database_connection, if_exists='replace')
aspirevc_crowd_tracing.to_sql('aspirevc_crowd_tracing', database_connection, if_exists='replace')
aspirevc_crowd_tracing_zipcode_3digits.to_sql('aspirevc_crowd_tracing_zipcode_3digits', database_connection, if_exists='replace')
cdc_moderna_vaccine_distribution.to_sql('cdc_moderna_vaccine_distribution', database_connection, if_exists='replace')
cdc_pfizer_vaccine_distribution.to_sql('cdc_pfizer_vaccine_distribution', database_connection, if_exists='replace')
country_codes.to_sql('country_codes', database_connection, if_exists='replace')
county_populations.to_sql('county_populations', database_connection, if_exists='replace')
covid_knowledge_graph_edges.to_sql('covid_knowledge_graph_edges', database_connection, if_exists='replace')
covid_knowledge_graph_nodes_author.to_sql('covid_knowledge_graph_nodes_author', database_connection, if_exists='replace')
covid_knowledge_graph_nodes_concept.to_sql('covid_knowledge_graph_nodes_concept', database_connection, if_exists='replace')
covid_knowledge_graph_nodes_institution.to_sql('covid_knowledge_graph_nodes_institution', database_connection, if_exists='replace')
covid_knowledge_graph_nodes_paper.to_sql('covid_knowledge_graph_nodes_paper', database_connection, if_exists='replace')
covid_knowledge_graph_nodes_topic.to_sql('covid_knowledge_graph_nodes_topic', database_connection, if_exists='replace')
covid_testing_states_daily.to_sql('covid_testing_states_daily', database_connection, if_exists='replace')
covid_testing_us_daily.to_sql('covid_testing_us_daily', database_connection, if_exists='replace')
covid_testing_us_total.to_sql('covid_testing_us_total', database_connection, if_exists='replace')
covidcast_data.to_sql('covidcast_data', database_connection, if_exists='replace')
covidcast_metadata.to_sql('covidcast_metadata', database_connection, if_exists='replace')
enigma_aggregation_global.to_sql('enigma_aggregation_global', database_connection, if_exists='replace')
enigma_aggregation_global_countries.to_sql('enigma_aggregation_global_countries', database_connection, if_exists='replace')
enigma_aggregation_us_counties.to_sql('enigma_aggregation_us_counties', database_connection, if_exists='replace')
enigma_aggregation_us_states.to_sql('enigma_aggregation_us_states', database_connection, if_exists='replace')
enigma_jhu.to_sql('enigma_jhu', database_connection, if_exists='replace')
enigma_jhu_timeseries.to_sql('enigma_jhu_timeseries', database_connection, if_exists='replace')
hospital_beds.to_sql('hospital_beds', database_connection, if_exists='replace')
nytimes_counties.to_sql('nytimes_counties', database_connection, if_exists='replace')
nytimes_states.to_sql('nytimes_states', database_connection, if_exists='replace')
owid_us_state_vaccinations.to_sql('owid_us_state_vaccinations', database_connection, if_exists='replace')
owid_world_vaccinations.to_sql('owid_world_vaccinations', database_connection, if_exists='replace')
owid_world_vaccinations_by_manufacturer.to_sql('owid_world_vaccinations_by_manufacturer', database_connection, if_exists='replace')
prediction_models_county_predictions.to_sql('prediction_models_county_predictions', database_connection, if_exists='replace')
prediction_models_severity_index.to_sql('prediction_models_severity_index', database_connection, if_exists='replace')
tableau_covid_datahub.to_sql('tableau_covid_datahub', database_connection, if_exists='replace')
tableau_jhu.to_sql('tableau_jhu', database_connection, if_exists='replace')
uk_covid.to_sql('uk_covid', database_connection, if_exists='replace')
us_state_abbreviations.to_sql('us_state_abbreviations', database_connection, if_exists='replace')
world_cases_deaths_testing.to_sql('world_cases_deaths_testing', database_connection, if_exists='replace')
